# %%
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from langchain_openai import ChatOpenAI
#
# File ~/Projects/faangfocus/backend/venv/lib/python3.12/site-packages/langchain_openai/__init__.py:3
#       1 """Module for OpenAI integrations."""
# ----> 3 from langchain_openai.chat_models import AzureChatOpenAI, ChatOpenAI
#       4 from langchain_openai.embeddings import AzureOpenAIEmbeddings, OpenAIEmbeddings
#       5 from langchain_openai.llms import AzureOpenAI, OpenAI
#
# File ~/Projects/faangfocus/backend/venv/lib/python3.12/site-packages/langchain_openai/chat_models/__init__.py:3
#       1 """Module for OpenAI chat models."""
# ----> 3 from langchain_openai.chat_models.azure import AzureChatOpenAI
#       4 from langchain_openai.chat_models.base import ChatOpenAI
#       6 __all__ = ["AzureChatOpenAI", "ChatOpenAI"]
#
# File ~/Projects/faangfocus/backend/venv/lib/python3.12/site-packages/langchain_openai/chat_models/azure.py:20
#      17 from pydantic import BaseModel, Field, SecretStr, model_validator
#      18 from typing_extensions import Self
# ---> 20 from langchain_openai.chat_models.base import BaseChatOpenAI
#      22 logger = logging.getLogger(__name__)
#      25 _BM = TypeVar("_BM", bound=BaseModel)
#
# File ~/Projects/faangfocus/backend/venv/lib/python3.12/site-packages/langchain_openai/chat_models/base.py:67
#      44 from langchain_core.language_models.chat_models import (
#      45     BaseChatModel,
#      46     LangSmithParams,
#      47 )
#      48 from langchain_core.messages import (
#      49     AIMessage,
#      50     AIMessageChunk,
#    (...)
#      65     is_data_content_block,
#      66 )
# ---> 67 from langchain_core.messages import content as types
#      68 from langchain_core.messages.ai import (
#      69     InputTokenDetails,
#      70     OutputTokenDetails,
#      71     UsageMetadata,
#      72 )
#      73 from langchain_core.messages.block_translators.openai import (
#      74     _convert_from_v03_ai_message,
#      75     convert_to_openai_data_block,
#      76 )
#
# File ~/Projects/faangfocus/backend/venv/lib/python3.12/site-packages/langchain_core/messages/__init__.py:144, in __getattr__(attr_name)
#      58     from langchain_core.messages.utils import (
#      59         AnyMessage,
#      60         MessageLikeRepresentation,
#    (...)
#      69         trim_messages,
#      70     )
#      72 __all__ = (
#      73     "LC_AUTO_PREFIX",
#      74     "LC_ID_PREFIX",
#    (...)
#     129     "trim_messages",
#     130 )
#     132 _dynamic_imports = {
#     133     "AIMessage": "ai",
#     134     "AIMessageChunk": "ai",
#     135     "Annotation": "content",
#     136     "AudioContentBlock": "content",
#     137     "BaseMessage": "base",
#     138     "BaseMessageChunk": "base",
#     139     "merge_content": "base",
#     140     "message_to_dict": "base",
#     141     "messages_to_dict": "base",
#     142     "Citation": "content",
#     143     "ContentBlock": "content",
# --> 144     "ChatMessage": "chat",
#     145     "ChatMessageChunk": "chat",
#     146     "DataContentBlock": "content",
#     147     "FileContentBlock": "content",
#     148     "FunctionMessage": "function",
#     149     "FunctionMessageChunk": "function",
#     150     "HumanMessage": "human",
#     151     "HumanMessageChunk": "human",
#     152     "NonStandardAnnotation": "content",
#     153     "NonStandardContentBlock": "content",
#     154     "OutputTokenDetails": "ai",
#     155     "PlainTextContentBlock": "content",
#     156     "ReasoningContentBlock": "content",
#     157     "RemoveMessage": "modifier",
#     158     "ServerToolCall": "content",
#     159     "ServerToolCallChunk": "content",
#     160     "ServerToolResult": "content",
#     161     "SystemMessage": "system",
#     162     "SystemMessageChunk": "system",
#     163     "ImageContentBlock": "content",
#     164     "InputTokenDetails": "ai",
#     165     "InvalidToolCall": "tool",
#     166     "TextContentBlock": "content",
#     167     "ToolCall": "tool",
#     168     "ToolCallChunk": "tool",
#     169     "ToolMessage": "tool",
#     170     "ToolMessageChunk": "tool",
#     171     "UsageMetadata": "ai",
#     172     "VideoContentBlock": "content",
#     173     "AnyMessage": "utils",
#     174     "MessageLikeRepresentation": "utils",
#     175     "_message_from_dict": "utils",
#     176     "convert_to_messages": "utils",
#     177     "convert_to_openai_data_block": "block_translators.openai",
#     178     "convert_to_openai_image_block": "block_translators.openai",
#     179     "convert_to_openai_messages": "utils",
#     180     "filter_messages": "utils",
#     181     "get_buffer_string": "utils",
#     182     "is_data_content_block": "content",
#     183     "merge_message_runs": "utils",
#     184     "message_chunk_to_message": "utils",
#     185     "messages_from_dict": "utils",
#     186     "trim_messages": "utils",
#     187 }
#     190 def __getattr__(attr_name: str) -> object:
#     191     module_name = _dynamic_imports.get(attr_name)
#
# File ~/Projects/faangfocus/backend/venv/lib/python3.12/site-packages/langchain_core/_import_utils.py:30, in import_attr(attr_name, module_name, package)
#      28 try:
#      29     result = import_module(f".{attr_name}", package=package)
# ---> 30 except ModuleNotFoundError:
#      31     msg = f"module '{package!r}' has no attribute {attr_name!r}"
#      32     raise AttributeError(msg) from None
#
# File ~/.pyenv/versions/3.12.10/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/Projects/faangfocus/backend/venv/lib/python3.12/site-packages/langchain_core/messages/content.py:135
#     131 from typing import Any, Literal, get_args, get_type_hints
#     133 from typing_extensions import NotRequired, TypedDict
# --> 135 from langchain_core.utils.utils import ensure_id
#     138 class Citation(TypedDict):
#     139     """Annotation for citing data from a document.
#     140
#     141     !!! note
#    (...)
#     152
#     153     """
#
# ImportError: cannot import name 'ensure_id' from 'langchain_core.utils.utils' (/Users/aryanjain/Projects/faangfocus/backend/venv/lib/python3.12/site-packages/langchain_core/utils/utils.py)
